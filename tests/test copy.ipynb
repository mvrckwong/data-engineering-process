# %%
from pathlib import Path

TEST_PATH = Path.cwd()
PROJECT_PATH:Path = TEST_PATH.parent

# Define other paths relative to the base path
DATA_PATH:Path = PROJECT_PATH / 'data'
DATA_RAW_PATH:Path = DATA_PATH / 'raw'
DATA_PROCESS_PATH:Path = DATA_PATH / 'processed'

LOGS_PATH:Path = PROJECT_PATH / 'logs'
OUTPUT_PATH:Path = PROJECT_PATH / '.output'

# %%
import pandas as pd

# %%
df = pd.read_parquet(DATA_PROCESS_PATH / 'dailycheckins.parquet')
df
# Out:
#       user_name project_date project_time  project_hours  \
# 0           ned   2019-09-27     00:00:00            8.0
# 1           ned   2019-09-26     00:00:00            1.0
# 2           ned   2019-09-26     00:00:00            1.5
# 3           ned   2019-09-26     00:00:00            1.0
# 4         jaime   2018-12-21     00:00:00            0.5
# ...         ...          ...          ...            ...
# 18443    robert   2010-10-04     00:00:00            2.0
# 18444    robert   2010-10-04     00:00:00            2.0
# 18445    robert   2010-10-04     00:00:00            2.0
# 18446    robert   2010-10-04     00:00:00            1.0
# 18447    robert   2010-10-04     00:00:00            6.0
#
#                project_name  is_project
# 0                    bizdev       False
# 1      cultureandmanagement       False
# 2                project-00        True
# 3                project-43        True
# 4                project-47        True
# ...                     ...         ...
# 18443            project-64        True
# 18444               transit       False
# 18445  cultureandmanagement       False
# 18446               transit       False
# 18447                bizdev       False
#
# [18448 rows x 6 columns]

# %%
import pandas as pd
from pathlib import Path
from dateutil import parser

# %%
def transform_df_timestamp(df:pd.DataFrame) -> pd.DataFrame: return None
def transform_df_date(df:pd.DataFrame) -> pd.DataFrame: return None
def transform_df_users(df:pd.DataFrame) -> pd.DataFrame: return None
def transform_df_user

# %%
# TODO: Transformation (might remove later). Move to transformation
df['timestamp'] = pd.to_datetime(df['timestamp'], errors='coerce', utc=True)
df['date'] = df['timestamp'].dt.date

# %%
""" TODO:
CHECK FOR THE FOLLOWING
- Data Type
- Data Format (if date, is it YYYY-MM-DD?. if float, how many decimals?)
- Nulls, Nans, Blanks, and Invalid
- Base, Ceiling and Zeros

- Replace Columns if not clear (use snake_case)
"""

# %%
TEST_PATH = Path.cwd()
PROJECT_PATH:Path = TEST_PATH.parent

# Define other paths relative to the base path
DATA_PATH:Path = PROJECT_PATH / 'data'
DATA_RAW_PATH:Path = DATA_PATH / 'raw'
DATA_PROCESS_PATH:Path = DATA_PATH / 'processed'

LOGS_PATH:Path = PROJECT_PATH / 'logs'
OUTPUT_PATH:Path = PROJECT_PATH / '.output'

# %%
df['timestamp'] = df['project_timestamp'].str.split('.')[0]

# %%
def rename_df_cols(input_df:pd.DataFrame) -> pd.DataFrame:
    """
    Renames the columns of the input dataframe according to the standard mapping provided in the standard_cols dictionary.
    """
    standard_cols = {
        'user': 'user_name', 
        'timestamp': 'project_timestamp',
        'hours': 'project_hours',
        'project': 'project_name'
    }
    
    return input_df.rename(columns=standard_cols, errors='raise')

df = pd.read_csv(DATA_RAW_PATH / 'dailycheckins.csv')
df = rename_df_cols(df)
df['old_project_timestamp'] = df['project_timestamp']

#df.head(20)

# %%
def replace_month_names(timestamp):
    months_map = {
        ' января ': '-01-',
        ' февраля ': '-02-',
        ' марта ': '-03-',
        ' апреля ': '-04-',
        ' мая ': '-05-',
        ' июня ': '-06-',
        ' июля ': '-07-',
        ' августа ': '-08-',
        ' сентября ': '-09-',
        ' октября ': '-10-',
        ' ноября ': '-11-',
        ' декабря ': '-12-'
    }
    
    for rus, eng in months_map.items():
        timestamp = timestamp.replace(rus, eng)
    return timestamp

# Apply the function to the timestamp column
df['timestamp'] = df['project_timestamp'].apply(replace_month_names)

# %%
# Out:
# /var/folders/zb/r6zwt9xn6dgfrg3kzcgyjgtc0000gn/T/ipykernel_52280/3820303726.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['project_timestamp'] = filtered_df['project_timestamp'].str.split('.', expand=True)[0] + ' UTC'
# /var/folders/zb/r6zwt9xn6dgfrg3kzcgyjgtc0000gn/T/ipykernel_52280/3820303726.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['project_timestamp'] = pd.to_datetime(filtered_df['project_timestamp'], errors='coerce', utc=True)
#       user_name         project_timestamp  project_hours  \
# 13      catelyn 2018-11-26 14:47:36+00:00           0.60
# 14      catelyn 2018-11-26 14:47:36+00:00           0.45
# 15      catelyn 2018-11-26 14:47:36+00:00           0.40
# 16      catelyn 2018-11-26 14:47:36+00:00           0.08
# 17      catelyn 2018-11-26 14:47:36+00:00           0.68
# ...         ...                       ...            ...
# 20472     jorah 2017-06-19 09:07:51+00:00           0.50
# 20473     jorah 2017-06-19 09:07:51+00:00           1.50
# 20474     jorah 2017-06-19 09:07:51+00:00           0.50
# 20475     jorah 2017-06-19 09:07:51+00:00           0.50
# 20476     jorah 2017-06-19 09:07:51+00:00           0.50
#
#                project_name           old_project_timestamp  \
# 13              opsandadmin    2018-11-26 14:47:36.0429 UTC
# 14              opsandadmin    2018-11-26 14:47:36.0429 UTC
# 15     cultureandmanagement    2018-11-26 14:47:36.0429 UTC
# 16                 security    2018-11-26 14:47:36.0429 UTC
# 17               project-43    2018-11-26 14:47:36.0429 UTC
# ...                     ...                             ...
# 20472           opsandadmin  2017-06-19 09:07:51.085966 UTC
# 20473             workshops  2017-06-19 09:07:51.085966 UTC
# 20474             workshops  2017-06-19 09:07:51.085966 UTC
# 20475            project-65  2017-06-19 09:07:51.085966 UTC
# 20476            project-65  2017-06-19 09:07:51.085966 UTC
#
#                             timestamp
# 13       2018-11-26 14:47:36.0429 UTC
# 14       2018-11-26 14:47:36.0429 UTC
# 15       2018-11-26 14:47:36.0429 UTC
# 16       2018-11-26 14:47:36.0429 UTC
# 17       2018-11-26 14:47:36.0429 UTC
# ...                               ...
# 20472  2017-06-19 09:07:51.085966 UTC
# 20473  2017-06-19 09:07:51.085966 UTC
# 20474  2017-06-19 09:07:51.085966 UTC
# 20475  2017-06-19 09:07:51.085966 UTC
# 20476  2017-06-19 09:07:51.085966 UTC
#
# [11621 rows x 6 columns]

# %%
filtered_df = df[df['project_timestamp'].str.contains('.', regex=False)]
filtered_df['project_timestamp'] = filtered_df['project_timestamp'].str.split('.', expand=True)[0] + ' UTC'
filtered_df['project_timestamp'] = pd.to_datetime(filtered_df['project_timestamp'], errors='coerce', utc=True)

df.update(filtered_df)
df['project_timestamp'] = pd.to_datetime(df['project_timestamp'], errors='coerce', utc=True)
df.to_csv(PROJECT_PATH / 'sample.csv', index=False)

# %%
filtered_df.to_csv(PROJECT_PATH / 'filter.csv', index=False)

# %%
# Check if the column contains a period
contains_period = df['project_timestamp'].str.contains('\.')

# Split the string at the period for those rows that contain a period
df.loc[contains_period, 'project_timestamp'] = df.loc[contains_period, 'project_timestamp'].str.split('.', expand=True)[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/range.py:345, in RangeIndex.get_loc(self, key)
#     344 try:
# --> 345     return self._range.index(new_key)
#     346 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[77], line 5
#       2 contains_period = df['project_timestamp'].str.contains('\.')
#       4 # Split the string at the period for those rows that contain a period
# ----> 5 df.loc[contains_period, 'project_timestamp'] = df.loc[contains_period, 'project_timestamp'].str.split('.', expand=True)[0]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/range.py:347, in RangeIndex.get_loc(self, key)
#     345         return self._range.index(new_key)
#     346     except ValueError as err:
# --> 347         raise KeyError(key) from err
#     348 if isinstance(key, Hashable):
#     349     raise KeyError(key)
#
# KeyError: 0

# %%
df
# Out:
#       user_name        project_timestamp  project_hours          project_name
# 0           ned  2019-09-27 00:00:00 UTC            8.0                bizdev
# 1        robert      09/27/2019 12:00 AM            8.0                bizdev
# 2           ned   26 сентября 2019 00:00            4.0                bizdev
# 3           ned  2019-09-26 00:00:00 UTC            1.0  cultureandmanagement
# 4           ned  2019-09-26 00:00:00 UTC            1.5            project-00
# ...         ...                      ...            ...                   ...
# 20495    robert  2010-10-04 00:00:00 UTC            2.0               transit
# 20496    robert  2010-10-04 00:00:00 UTC            2.0  cultureandmanagement
# 20497    robert     4 октября 2010 00:00            1.5                bizdev
# 20498    robert  2010-10-04 00:00:00 UTC            1.0               transit
# 20499    robert  2010-10-04 00:00:00 UTC            6.0                bizdev
#
# [20500 rows x 4 columns]

# %%
df['project_timestamp'] == '.'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 20495    False
# 20496    False
# 20497    False
# 20498    False
# 20499    False
# Name: project_timestamp, Length: 20500, dtype: bool

# %%
df['timestamp'] = df['project_timestamp'].str.split('.')[0] + ' UTC'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 df['timestamp'] = df['project_timestamp'].str.split('.')[0] + ' UTC'
#
# TypeError: can only concatenate list (not "str") to list

# %%
#Convert the date column to datetime, which will standardize the format
df['timestamp'] = pd.to_datetime(df['project_timestamp'], errors='coerce', utc=True)

# %%
# Convert the date column to datetime, which will standardize the format
#df['timestamp'] = pd.to_datetime(df['timestamp'], errors='coerce', utc=True)

# If you want to maintain a specific format, for example 'YYYY-MM-DD', you can do:
#df['timestamp'] = df['timestamp'].dt.strftime('%Y-%m-%d')

# %%
df.to_csv(PROJECT_PATH / 'sample.csv', index=False)

# %%
df['project_timestamp'] = df['project_timestamp'].str.replace('/', '-')
df.head(3)
# Out:
#   user_name        project_timestamp  project_hours project_name  \
# 0       ned  2019-09-27 00:00:00 UTC            8.0       bizdev
# 1    robert      09-27-2019 12:00 AM            8.0       bizdev
# 2       ned   26 сентября 2019 00:00            4.0       bizdev
#
#                  timestamp
# 0  2019-09-27 00:00:00 UTC
# 1      09-27-2019 12:00 AM
# 2   26 сентября 2019 00:00

# %%
months_map = {
    'января': 'January',
    'февраля': 'February',
    'марта': 'March',
    'апреля': 'April',
    'мая': 'May',
    'июня': 'June',
    'июля': 'July',
    'августа': 'August',
    'сентября': 'September',
    'октября': 'October',
    'ноября': 'November',
    'декабря': 'December'
}

months_map = {
    'января': '01',
    'февраля': '02',
    'марта': '03',
    'апреля': '04',
    'мая': '05',
    'июня': '06',
    'июля': '07',
    'августа': '08',
    'сентября': '09',
    'октября': '10',
    'ноября': '11',
    'декабря': '12'
}

# %%
def replace_month_names(timestamp):
    for rus, eng in months_map.items():
        timestamp = timestamp.replace(rus, eng)
    return timestamp

# Apply the function to the timestamp column
df['timestamp'] = df['project_timestamp'].apply(replace_month_names)

# # Convert the timestamp column to datetime
df['timestamp'] = pd.to_datetime(df['timestamp'], errors='coerce', utc=True)

# %%
df.to_csv(PROJECT_PATH / 'sample.csv', index=False)

# %%
df['sample_timestamp'] = pd.to_datetime(df['project_timestamp'], errors='coerce', utc=True)

# %%
def parse_date_with_locale(date_str):
    try:
        # Attempt to parse the date string
        return parser.parse(date_str)
    except ValueError:
        # Handle the case where parsing fails
        return pd.NaT

# # Apply the parsing function to each date string
df['parsed_timestamp'] = df['timestamp'].apply(parse_date_with_locale)
df['parsed_timestamp'] = pd.to_datetime(df['parsed_timestamp'], errors='coerce', utc=True)
df['parsed_timestamp'] = df['parsed_timestamp'].dt.normalize()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'timestamp'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[78], line 10
#       7         return pd.NaT
#       9 # # Apply the parsing function to each date string
# ---> 10 df['parsed_timestamp'] = df['timestamp'].apply(parse_date_with_locale)
#      11 df['parsed_timestamp'] = pd.to_datetime(df['parsed_timestamp'], errors='coerce', utc=True)
#      12 df['parsed_timestamp'] = df['parsed_timestamp'].dt.normalize()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'timestamp'

# %%
# Parse the timestamps into datetime objects, including the timezone
df['another_timestamp'] = pd.to_datetime(df['project_timestamp'], utc=True, errors='coerce')

# Normalize the timestamps to midnight
df['another_timestamp'] = df['another_timestamp'].dt.normalize()

# %%
df.to_csv(PROJECT_PATH / 'sample.csv', index=False)

# %%
df.dtypes
# Out:
# user_name                         object
# project_timestamp                 object
# project_hours                    float64
# project_name                      object
# timestamp                         object
# random_timestamp     datetime64[ns, UTC]
# sample_timestamp     datetime64[ns, UTC]
# parsed_timestamp     datetime64[ns, UTC]
# another_timestamp    datetime64[ns, UTC]
# dtype: object

# %%
df
# Out:
#       user_name        project_timestamp  project_hours          project_name  \
# 0           ned  2019-09-27 00:00:00 UTC            8.0                bizdev
# 1        robert      09/27/2019 12:00 AM            8.0                bizdev
# 2           ned   26 сентября 2019 00:00            4.0                bizdev
# 3           ned  2019-09-26 00:00:00 UTC            1.0  cultureandmanagement
# 4           ned  2019-09-26 00:00:00 UTC            1.5            project-00
# ...         ...                      ...            ...                   ...
# 20495    robert  2010-10-04 00:00:00 UTC            2.0               transit
# 20496    robert  2010-10-04 00:00:00 UTC            2.0  cultureandmanagement
# 20497    robert     4 октября 2010 00:00            1.5                bizdev
# 20498    robert  2010-10-04 00:00:00 UTC            1.0               transit
# 20499    robert  2010-10-04 00:00:00 UTC            6.0                bizdev
#
#                      timestamp          random_timestamp  \
# 0      2019-09-27 00:00:00 UTC 2019-09-27 00:00:00+00:00
# 1          09/27/2019 12:00 AM                       NaT
# 2             26 09 2019 00:00                       NaT
# 3      2019-09-26 00:00:00 UTC 2019-09-26 00:00:00+00:00
# 4      2019-09-26 00:00:00 UTC 2019-09-26 00:00:00+00:00
# ...                        ...                       ...
# 20495  2010-10-04 00:00:00 UTC 2010-10-04 00:00:00+00:00
# 20496  2010-10-04 00:00:00 UTC 2010-10-04 00:00:00+00:00
# 20497          4 10 2010 00:00                       NaT
# 20498  2010-10-04 00:00:00 UTC 2010-10-04 00:00:00+00:00
# 20499  2010-10-04 00:00:00 UTC 2010-10-04 00:00:00+00:00
#
#                sample_timestamp          parsed_timestamp  \
# 0     2019-09-27 00:00:00+00:00 2019-09-27 00:00:00+00:00
# 1                           NaT 2019-09-27 00:00:00+00:00
# 2                           NaT 2019-09-26 00:00:00+00:00
# 3     2019-09-26 00:00:00+00:00 2019-09-26 00:00:00+00:00
# 4     2019-09-26 00:00:00+00:00 2019-09-26 00:00:00+00:00
# ...                         ...                       ...
# 20495 2010-10-04 00:00:00+00:00 2010-10-04 00:00:00+00:00
# 20496 2010-10-04 00:00:00+00:00 2010-10-04 00:00:00+00:00
# 20497                       NaT 2010-04-10 00:00:00+00:00
# 20498 2010-10-04 00:00:00+00:00 2010-10-04 00:00:00+00:00
# 20499 2010-10-04 00:00:00+00:00 2010-10-04 00:00:00+00:00
#
#               another_timestamp
# 0     2019-09-27 00:00:00+00:00
# 1                           NaT
# 2                           NaT
# 3     2019-09-26 00:00:00+00:00
# 4     2019-09-26 00:00:00+00:00
# ...                         ...
# 20495 2010-10-04 00:00:00+00:00
# 20496 2010-10-04 00:00:00+00:00
# 20497                       NaT
# 20498 2010-10-04 00:00:00+00:00
# 20499 2010-10-04 00:00:00+00:00
#
# [20500 rows x 9 columns]

# %%
df['new_datetime'] = df['project_timestamp'].dt.floor('S')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[182], line 1
# ----> 1 df['new_datetime'] = df['project_timestamp'].dt.floor('S')
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/accessors.py:580, in CombinedDatetimelikeProperties.__new__(cls, data)
#     577 elif is_period_dtype(data.dtype):
#     578     return PeriodProperties(data, orig)
# --> 580 raise AttributeError("Can only use .dt accessor with datetimelike values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %%
df.head()
# Out:
#   user_name        project_timestamp  project_hours          project_name  \
# 0       ned  2019-09-27 00:00:00 UTC            8.0                bizdev
# 1    robert      09/27/2019 12:00 AM            8.0                bizdev
# 2       ned   26 сентября 2019 00:00            4.0                bizdev
# 3       ned  2019-09-26 00:00:00 UTC            1.0  cultureandmanagement
# 4       ned  2019-09-26 00:00:00 UTC            1.5            project-00
#
#                  timestamp          random_timestamp  \
# 0  2019-09-27 00:00:00 UTC 2019-09-27 00:00:00+00:00
# 1      09/27/2019 12:00 AM                       NaT
# 2         26 09 2019 00:00                       NaT
# 3  2019-09-26 00:00:00 UTC 2019-09-26 00:00:00+00:00
# 4  2019-09-26 00:00:00 UTC 2019-09-26 00:00:00+00:00
#
#            sample_timestamp          parsed_timestamp  \
# 0 2019-09-27 00:00:00+00:00 2019-09-27 00:00:00+00:00
# 1                       NaT 2019-09-27 00:00:00+00:00
# 2                       NaT 2019-09-26 00:00:00+00:00
# 3 2019-09-26 00:00:00+00:00 2019-09-26 00:00:00+00:00
# 4 2019-09-26 00:00:00+00:00 2019-09-26 00:00:00+00:00
#
#           another_timestamp
# 0 2019-09-27 00:00:00+00:00
# 1                       NaT
# 2                       NaT
# 3 2019-09-26 00:00:00+00:00
# 4 2019-09-26 00:00:00+00:00

# %%
df['project_timestamp'] = pd.to_datetime(df['project_timestamp'])

# Now, you can use .dt.floor() to round down to the nearest second
# df['new_datetime'] = df['project_timestamp'].dt.floor('S')

# # If you need to round or convert to a specific precision
# # Method 2: Using dt.round() to round to the nearest second
# df['rounded_datetime'] = df['project_timestamp'].dt.round('S')

# # Method 3: Converting to datetime64[s] to truncate to the nearest second
# df['converted_datetime'] = df['project_timestamp'].astype('datetime64[s]')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[184], line 1
# ----> 1 df['project_timestamp'] = pd.to_datetime(df['project_timestamp'])
#       3 # Now, you can use .dt.floor() to round down to the nearest second
#       4 # df['new_datetime'] = df['project_timestamp'].dt.floor('S')
#       5
#    (...)
#      10 # # Method 3: Converting to datetime64[s] to truncate to the nearest second
#      11 # df['converted_datetime'] = df['project_timestamp'].astype('datetime64[s]')
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/tools/datetimes.py:1046, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1044             result = arg.tz_localize("utc")
#    1045 elif isinstance(arg, ABCSeries):
# -> 1046     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1047     if not cache_array.empty:
#    1048         result = arg.map(cache_array)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/tools/datetimes.py:250, in _maybe_cache(arg, format, cache, convert_listlike)
#     248 unique_dates = unique(arg)
#     249 if len(unique_dates) < len(arg):
# --> 250     cache_dates = convert_listlike(unique_dates, format)
#     251     # GH#45319
#     252     try:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/tools/datetimes.py:453, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     451 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     452 if format is not None and format != "mixed":
# --> 453     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     455 result, tz_parsed = objects_to_datetime64ns(
#     456     arg,
#     457     dayfirst=dayfirst,
#    (...)
#     461     allow_object=True,
#     462 )
#     464 if tz_parsed is not None:
#     465     # We can take a shortcut since the datetime64 numpy array
#     466     # is in UTC
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/tools/datetimes.py:484, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     473 def _array_strptime_with_fallback(
#     474     arg,
#     475     name,
#    (...)
#     479     errors: str,
#     480 ) -> Index:
#     481     """
#     482     Call array_strptime, with fallback behavior depending on 'errors'.
#     483     """
# --> 484     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     485     if any(tz is not None for tz in timezones):
#     486         return _return_parsed_timezone_results(result, timezones, utc, name)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/_libs/tslibs/strptime.pyx:530, in pandas._libs.tslibs.strptime.array_strptime()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/_libs/tslibs/strptime.pyx:351, in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data "09/27/2019 12:00 AM" doesn't match format "%Y-%m-%d %H:%M:%S %Z", at position 1. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
df['another'] = pd.to_datetime(df['timestamp'], errors='ignore')
#df['another'] = df['another'].dt.normalize() + pd.Timedelta(days=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[191], line 2
#       1 df['another'] = pd.to_datetime(df['timestamp'], errors='ignore')
# ----> 2 df['another'] = df['another'].dt.normalize() + pd.Timedelta(days=1)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/accessors.py:580, in CombinedDatetimelikeProperties.__new__(cls, data)
#     577 elif is_period_dtype(data.dtype):
#     578     return PeriodProperties(data, orig)
# --> 580 raise AttributeError("Can only use .dt accessor with datetimelike values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %%
df.dtypes
# Out:
# user_name                         object
# project_timestamp                 object
# project_hours                    float64
# project_name                      object
# timestamp                         object
# random_timestamp     datetime64[ns, UTC]
# sample_timestamp     datetime64[ns, UTC]
# parsed_timestamp     datetime64[ns, UTC]
# another_timestamp    datetime64[ns, UTC]
# another                           object
# dtype: object

# %%
df.to_csv(PROJECT_PATH / 'sample.csv', index=False)

# %%
df = pd.read_csv(DATA_RAW_PATH / 'dailycheckins.csv')
df = rename_df_cols(df)
df
# Out:
#       user_name        project_timestamp  project_hours          project_name
# 0           ned  2019-09-27 00:00:00 UTC            8.0                bizdev
# 1        robert      09/27/2019 12:00 AM            8.0                bizdev
# 2           ned   26 сентября 2019 00:00            4.0                bizdev
# 3           ned  2019-09-26 00:00:00 UTC            1.0  cultureandmanagement
# 4           ned  2019-09-26 00:00:00 UTC            1.5            project-00
# ...         ...                      ...            ...                   ...
# 20495    robert  2010-10-04 00:00:00 UTC            2.0               transit
# 20496    robert  2010-10-04 00:00:00 UTC            2.0  cultureandmanagement
# 20497    robert     4 октября 2010 00:00            1.5                bizdev
# 20498    robert  2010-10-04 00:00:00 UTC            1.0               transit
# 20499    robert  2010-10-04 00:00:00 UTC            6.0                bizdev
#
# [20500 rows x 4 columns]

# %%
df['another'] = pd.to_datetime(df['project_timestamp'], errors='coerce')

# %%
df.to_csv(PROJECT_PATH / 'sample.csv', index=False)

# %%
problem_df = df[df['another'].isna()].drop(columns=['another'])

# %%
def parse_date_with_locale(date_str):
    try:
        # Attempt to parse the date string
        return parser.parse(date_str)
    except ValueError:
        # Handle the case where parsing fails
        return date_str

# Apply the parsing function to each date string
df['parsed_timestamp'] = df['project_timestamp'].apply(parse_date_with_locale)
df['parsed_timestamp'] = pd.to_datetime(df['parsed_timestamp'], errors='coerce', utc=True)
df['parsed_timestamp'] = df['parsed_timestamp'].dt.normalize()

# %%
months_map = {
    ' января ': '-01-',
    ' февраля ': '-02-',
    ' марта ': '-03-',
    ' апреля ': '-04-',
    ' мая ': '-05-',
    ' июня ': '-06-',
    ' июля ': '-07-',
    ' августа ': '-08-',
    ' сентября ': '-09-',
    ' октября ': '-10-',
    ' ноября ': '-11-',
    ' декабря ': '-12-'
}

# %%
def replace_month_names(timestamp):
    for rus, eng in months_map.items():
        timestamp = timestamp.replace(rus, eng)
    return timestamp

# Apply the function to the timestamp column
df['timestamp'] = df['project_timestamp'].apply(replace_month_names)

# # Convert the timestamp column to datetime
df['random_timestamp'] = pd.to_datetime(df['timestamp'], errors='coerce', utc=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/extension.py:161, in ExtensionIndex.map(self, mapper, na_action)
#     160 try:
# --> 161     result = mapper(self)
#     163     # Try to use this result if we can
#
# Cell In[162], line 3, in replace_month_names(timestamp)
#       2 for rus, eng in months_map.items():
# ----> 3     timestamp = timestamp.replace(rus, eng)
#       4 return timestamp
#
# AttributeError: 'DatetimeIndex' object has no attribute 'replace'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[162], line 7
#       4     return timestamp
#       6 # Apply the function to the timestamp column
# ----> 7 df['timestamp'] = df['project_timestamp'].apply(replace_month_names)
#       9 # # Convert the timestamp column to datetime
#      10 df['random_timestamp'] = pd.to_datetime(df['timestamp'], errors='coerce', utc=False)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/series.py:4630, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4520 def apply(
#    4521     self,
#    4522     func: AggFuncType,
#    (...)
#    4525     **kwargs,
#    4526 ) -> DataFrame | Series:
#    4527     """
#    4528     Invoke function on values of Series.
#    4529
#    (...)
#    4628     dtype: float64
#    4629     """
# -> 4630     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/apply.py:1073, in SeriesApply.apply_standard(self)
#    1070 # row-wise access
#    1071 if is_extension_array_dtype(obj.dtype) and hasattr(obj._values, "map"):
#    1072     # GH#23179 some EAs do not have `map`
# -> 1073     mapped = obj._values.map(f)
#    1074 else:
#    1075     values = obj.astype(object)._values
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/arrays/_mixins.py:86, in ravel_compat.<locals>.method(self, *args, **kwargs)
#      83 @wraps(meth)
#      84 def method(self, *args, **kwargs):
#      85     if self.ndim == 1:
# ---> 86         return meth(self, *args, **kwargs)
#      88     flags = self._ndarray.flags
#      89     flat = self.ravel("K")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/arrays/datetimelike.py:761, in DatetimeLikeArrayMixin.map(self, mapper)
#     752 @ravel_compat
#     753 def map(self, mapper):
#     754     # TODO(GH-23179): Add ExtensionArray.map
#    (...)
#     757     # a standalone function and call from here..
#     758     # Else, just rewrite _map_infer_values to do the right thing.
#     759     from pandas import Index
# --> 761     return Index(self).map(mapper).array
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/extension.py:171, in ExtensionIndex.map(self, mapper, na_action)
#     169     return result
#     170 except Exception:
# --> 171     return self.astype(object).map(mapper)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:6161, in Index.map(self, mapper, na_action)
#    6141 """
#    6142 Map values using an input mapping or function.
#    6143
#    (...)
#    6157     a MultiIndex will be returned.
#    6158 """
#    6159 from pandas.core.indexes.multi import MultiIndex
# -> 6161 new_values = self._map_values(mapper, na_action=na_action)
#    6163 # we can return a MultiIndex
#    6164 if new_values.size and isinstance(new_values[0], tuple):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/base.py:924, in IndexOpsMixin._map_values(self, mapper, na_action)
#     921         raise ValueError(msg)
#     923 # mapper is a function
# --> 924 new_values = map_f(values, mapper)
#     926 return new_values
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/_libs/lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# Cell In[162], line 3, in replace_month_names(timestamp)
#       1 def replace_month_names(timestamp):
#       2     for rus, eng in months_map.items():
# ----> 3         timestamp = timestamp.replace(rus, eng)
#       4     return timestamp
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/_libs/tslibs/timestamps.pyx:2251, in pandas._libs.tslibs.timestamps.Timestamp.replace()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/_libs/tslibs/timestamps.pyx:2245, in pandas._libs.tslibs.timestamps.Timestamp.replace.validate()
#
# ValueError: value must be an integer, received <class 'str'> for year

# %%
df.to_csv(PROJECT_PATH / 'sample.csv', index=False)

# %%
orig_df = pd.read_csv(PROJECT_PATH / 'sample.csv')
df = orig_df[orig_df['project_timestamp'].isna()]
df.head(10)
# Out:
#    user_name project_timestamp  project_hours project_name  \
# 1     robert               NaN           8.00       bizdev
# 2        ned               NaN           4.00       bizdev
# 6      jaime               NaN           2.00   project-00
# 20   catelyn               NaN           0.72  opsandadmin
# 28     jorah               NaN           2.00   project-51
# 38   viserys               NaN           0.50  opsandadmin
# 42   viserys               NaN           1.00   project-51
# 50     jaime               NaN           1.80     learning
# 65     sansa               NaN           2.00      transit
# 91   catelyn               NaN           2.37   project-40
#
#      old_project_timestamp            timestamp
# 1      09/27/2019 12:00 AM  09/27/2019 12:00 AM
# 2   26 сентября 2019 00:00     26-09-2019 00:00
# 6      12/21/2018 12:00 AM  12/21/2018 12:00 AM
# 20    26 ноября 2018 14:47     26-11-2018 14:47
# 28     11/26/2018 12:49 PM  11/26/2018 12:49 PM
# 38    26 ноября 2018 12:30     26-11-2018 12:30
# 42     11/26/2018 12:30 PM  11/26/2018 12:30 PM
# 50    26 ноября 2018 12:11     26-11-2018 12:11
# 65     11/26/2018 11:48 AM  11/26/2018 11:48 AM
# 91    23 ноября 2018 13:12     23-11-2018 13:12

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'], errors='coerce', utc=True)
orig_df.update(df)
orig_df.to_csv(PROJECT_PATH / 'final.csv', index=False)
# Out:
# /var/folders/zb/r6zwt9xn6dgfrg3kzcgyjgtc0000gn/T/ipykernel_52280/4050818613.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['timestamp'] = pd.to_datetime(df['timestamp'], errors='coerce', utc=True, format='%m/%d/%y %H:%M')

# %%
orig_df.dtypes
# Out:
# user_name                 object
# project_timestamp         object
# project_hours            float64
# project_name              object
# old_project_timestamp     object
# timestamp                 object
# dtype: object
